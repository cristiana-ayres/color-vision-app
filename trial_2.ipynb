# %%
import numpy as np
import matplotlib.pyplot as plt

import skfuzzy as fuzz
from skfuzzy import control as ctrl
import colorsys

# %%
"""
Antecedents HSV
HUE: color represented by number from 0(red) - 360(violet)
{ WARM, COOL }

SATURATION: color saturation represented by number from 0(faded/gray color) - 100(full color)
{ GRAY, VERY_FADED, FADED, SATURATED, VERY_SATURATED }

VALUE: brightness represented by number 0(dark) - 100(light)
{ BLACK, VERY_DARK, DARK, BRIGHT, VERY_BRIGHT }
"""

hue_range = np.arange(0, 361, 1)
hue_fuzzy = ['WARM', 'COOL', 'WARM_']
hue = ctrl.Antecedent(hue_range, 'hue')
hue['WARM'] = fuzz.gaussmf(hue.universe, 0, 60)
hue['COOL'] = fuzz.gaussmf(hue.universe, 180, 60)
hue['WARM_'] = fuzz.gaussmf(hue.universe, 360, 60)


sat = ctrl.Antecedent(np.arange(0, 101, 1), 'saturation')
sat_fuzzy = ['GRAY', 'VERY_FADED', 'FADED', 'SATURATED', 'VERY_SATURATED']
sat['GRAY'] = fuzz.gaussmf(sat.universe, 0, 10)
sat['VERY_FADED'] = fuzz.gaussmf(sat.universe, 25, 10)
sat['FADED'] = fuzz.gaussmf(sat.universe, 50, 10)
sat['SATURATED'] = fuzz.gaussmf(sat.universe, 75, 10)
sat['VERY_SATURATED'] = fuzz.gaussmf(sat.universe, 100, 10)


val = ctrl.Antecedent(np.arange(0, 101, 1), 'value')
val_fuzzy = ['BLACK', 'VERY_DARK', 'DARK', 'BRIGHT', 'VERY_BRIGHT']
val['BLACK'] = fuzz.gaussmf(val.universe, 0, 10)
val['VERY_DARK'] = fuzz.gaussmf(val.universe, 25, 10)
val['DARK'] = fuzz.gaussmf(val.universe, 50, 10)
val['BRIGHT'] = fuzz.gaussmf(val.universe, 75, 10)
val['VERY_BRIGHT'] = fuzz.gaussmf(val.universe, 100, 10)

# %%
hue.view()
sat.view()
val.view()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [60], line 1
# ----> 1 hue.view()
#       2 sat.view()
#       3 val.view()
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\skfuzzy\control\fuzzyvariable.py:121, in FuzzyVariable.view(self, *args, **kwargs)
#     119 def view(self, *args, **kwargs):
#     120     """""" + FuzzyVariableVisualizer.view.__doc__
# --> 121     fig, ax = FuzzyVariableVisualizer(self).view(*args, **kwargs)
#     122     fig.show()
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\skfuzzy\control\visualization.py:49, in FuzzyVariableVisualizer.__init__(self, fuzzy_var)
#      45 else:
#      46     raise ValueError("`FuzzyVariableVisualizer` can only be called "
#      47                      "with a `FuzzyVariable` or a `Term`.")
# ---> 49 self.fig, self.ax = plt.subplots()
#      50 self.plots = {}
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %%
"""
Consequents
TONE: mix of Saturation and Value that indicate if color is neutral or dark/bright
{ NEUTRAL, DARK, BRIGHT }
"""
tone_range = np.arange(0, 12, 1)
tone_fuzzy = ['NEUTRAL', 'DARK', 'BRIGHT']
tone = ctrl.Consequent(tone_range, 'tone')

tone['NEUTRAL'] = fuzz.trapmf(tone.universe, [0, 0, 1, 2])
tone['DARK'] = fuzz.gbellmf(tone.universe, 2, 1, 3)
tone['BRIGHT'] = fuzz.gbellmf(tone.universe, 4, 1, 9.5)
tone['NEUTRAL_'] = fuzz.trimf(tone.universe, [10, 11, 11])

# %%
tone.view()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 tone.view()
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\skfuzzy\control\fuzzyvariable.py:121, in FuzzyVariable.view(self, *args, **kwargs)
#     119 def view(self, *args, **kwargs):
#     120     """""" + FuzzyVariableVisualizer.view.__doc__
# --> 121     fig, ax = FuzzyVariableVisualizer(self).view(*args, **kwargs)
#     122     fig.show()
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\skfuzzy\control\visualization.py:49, in FuzzyVariableVisualizer.__init__(self, fuzzy_var)
#      45 else:
#      46     raise ValueError("`FuzzyVariableVisualizer` can only be called "
#      47                      "with a `FuzzyVariable` or a `Term`.")
# ---> 49 self.fig, self.ax = plt.subplots()
#      50 self.plots = {}
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %% [markdown]
# # color identification

# %%
"""
Fuzzy rules
for tones
"""
rule1 = ctrl.Rule(val['BLACK'] | sat['GRAY'] | sat['VERY_FADED'], tone['NEUTRAL'], 'Dark colors without color (low brightness/dark) considered neutral')
rule2 = ctrl.Rule(val['VERY_DARK'] & sat['SATURATED'], tone['NEUTRAL'], 'Very dark colors with high saturation')
rule3 = ctrl.Rule(val['DARK'] & sat['FADED'], tone['DARK'], 'Dark color with normal saturation')
rule4 = ctrl.Rule(val['DARK'] & sat['VERY_SATURATED'], tone['BRIGHT'], 'Dark color with high saturation')
rule5 = ctrl.Rule(val['BRIGHT'] & sat['SATURATED'], tone['BRIGHT'], 'Bright color with high saturation')
rule6 = ctrl.Rule(val['VERY_BRIGHT'] & sat['FADED'], tone['BRIGHT'], 'Very bright color with some saturation')
rule7 = ctrl.Rule(val['VERY_BRIGHT'] & sat['VERY_SATURATED'], tone['BRIGHT'], 'Very bright color with high saturation')
rule8 = ctrl.Rule(val['VERY_DARK'] & sat['FADED'], tone['NEUTRAL'], 'Very dark color with faded saturation')

# %%
"""
Control system
for tones
"""
tone_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8])

# %%
"""
Simulation
for tones
"""
tone_sim = ctrl.ControlSystemSimulation(tone_ctrl)

# test
tone_sim.input['saturation'] = 33
tone_sim.input['value'] = 97
tone_sim.compute()
tone_output = tone_sim.output['tone']
print(tone_output)
# Out:
# 4.401875643979323

# %%
tone.view(sim=tone_sim)

# %%
"""
GetMembership
Returns String representing the Fuzzy value given a variable's range, model, and crisp value
"""
def GetMembership(fuzzy_values, var_range, var_model, crisp_value):
    max_membership = 0
    membership_name = fuzzy_values[0]
    for i in range(len(fuzzy_values)):
        temp_memb = fuzz.interp_membership(var_range, var_model[fuzzy_values[i]].mf, crisp_value)
        if temp_memb > max_membership:
            max_membership = temp_memb
            membership_name = fuzzy_values[i]
    return membership_name

# %%
print(GetMembership(tone_fuzzy, tone_range, tone, tone_output))
# Out:
# DARK

# %% [markdown]
# # API

# %%
"""
Given Saturation and Value, returns a String indicating if the combination 
of both values results in a 'NEUTRAL', 'DARK', or 'BRIGHT' tone.
INPUT:
values - tuple(sat, val)
    + sat - value from 0-100
    + val - value from 0-100
verbose - prints both crisp value and fuzzy value
"""
def GetTone(values, verbose=False):
    tone_sim = ctrl.ControlSystemSimulation(tone_ctrl)
    tone_sim.input['saturation'] = values[0]
    tone_sim.input['value'] = values[1]
    tone_sim.compute()
    tone_output = tone_sim.output['tone']
    tone_membership = GetMembership(tone_fuzzy, tone_range, tone, tone_output)
    if verbose:
        print("TONE CRISP VALUE: ", tone_output)
        print("TONE FUZZY VALUE: ", tone_membership)
    return tone_membership

# %%
GetTone((96, 76), verbose=True)
# Out:
# TONE CRISP VALUE:  5.500000000000002
# TONE FUZZY VALUE:  BRIGHT
# 'BRIGHT'

# %%
"""
Given Hue, returns a String indicating if the color belongs
to 'WARM' or 'COOL' colors.
INPUT:
hue - value from 0-360
verbose - prints both crisp value and fuzzy value
"""
def GetColorTemp(hue_val, verbose=False):
    temp_membership = GetMembership(hue_fuzzy, hue_range, hue, hue_val)
    if verbose:
        print("TEMP. CRISP VALUE: ", hue_val)
        print("TEMP. FUZZY VALUE: ", temp_membership)
    return temp_membership

# %%
GetColorTemp(200, verbose=True)
# Out:
# TEMP. CRISP VALUE:  200
# TEMP. FUZZY VALUE:  COOL
# 'COOL'

# %%
"""
Given Hue, Saturation, and Value, returns a String describing
the specified color. The output is composed of both the tone of
the color, and the temperature of the color.
INPUT:
hsv - tuple(hue, sat, val)
    + hue - value from 0-360
    + sat - value from 0-100
    + val - value from 0-100
OUTPUT: (TONE, TEMP) ex. (DARK, WARM)
"""
def GetColorDesc(hsv):
    tone = GetTone((hsv[1], hsv[2]))
    temp = GetColorTemp(hsv[0])
    if temp == "WARM_": temp = "WARM"
    return (tone, temp)

# %%
GetColorDesc((57, 72, 75))
# Out:
# ('BRIGHT', 'WARM')

# %%
"""
Helper function that displays a colored block given a color
represented in HSV format
INPUT:
hsv - tuple(hue, sat, val)
"""
def ShowColor(hsv):
    rgb = colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0)
    fig, ax = plt.subplots(nrows=1, ncols=1)
    fig.set_size_inches(3, 2)
    ax.set_facecolor(rgb)
    plt.tick_params(
        left=False,
        bottom=False,
        labelleft=False,
        labelbottom=False)
    plt.title('HSV'+str(hsv))
    plt.show()

# %%
ShowColor((200, 10, 100))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 ShowColor((200, 10, 100))
#
# Cell In [28], line 9, in ShowColor(hsv)
#       7 def ShowColor(hsv):
#       8     rgb = colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0)
# ----> 9     fig, ax = plt.subplots(nrows=1, ncols=1)
#      10     fig.set_size_inches(3, 2)
#      11     ax.set_facecolor(rgb)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %%
"""
Given Hue, Saturation, and Value, displays a block with the specified HSV color
and prints its color description
INPUT:
hsv - tuple(hue, sat, val)
    + hue - value from 0-360
    + sat - value from 0-100
    + val - value from 0-100
"""
def ShowColorWithDesc(hsv):
    ShowColor(hsv)
    print(GetColorDesc(hsv))

# %%
ShowColorWithDesc((372, 70, 50))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 ShowColorWithDesc((372, 70, 50))
#
# Cell In [30], line 11, in ShowColorWithDesc(hsv)
#      10 def ShowColorWithDesc(hsv):
# ---> 11     ShowColor(hsv)
#      12     print(GetColorDesc(hsv))
#
# Cell In [28], line 9, in ShowColor(hsv)
#       7 def ShowColor(hsv):
#       8     rgb = colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0)
# ----> 9     fig, ax = plt.subplots(nrows=1, ncols=1)
#      10     fig.set_size_inches(3, 2)
#      11     ax.set_facecolor(rgb)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %%
"""
Print colors of a complete outfit in a horizontal bar chart
INPUT:
outfit - tuple(top, bot, shs)
    + top - hsv
    + bot - hsv
    + shs - hsv
"""
def DisplayOutfitColors(outfit, valid_matches=[]):
    colors = [colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0) for hsv in outfit]

    plt.rcdefaults()
    fig, ax = plt.subplots()

    clothing = ('TOP', 'BOTTOM', 'SHOES')
    y_pos = np.arange(len(clothing))
    bar_width = [1, 1, 1]

    ax.barh(y_pos, bar_width, align='center', color=colors, height=0.99)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(clothing)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_title('Outfit color scheme')
    ax.set_facecolor((0.8,0.8,0.8))

    plt.tick_params(
            left=True,
            bottom=False,
            labelleft=True,
            labelbottom=False)
    plt.margins(y=0, x=0)

    plt.show()
    
    print("Valid outfit color schemes: ", valid_matches)

# %%
top_hsv = (206, 19, 93)
bot_hsv = (30, 21, 71)
shs_hsv = (84, 1, 99)

DisplayOutfitColors((top_hsv, bot_hsv, shs_hsv))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [33], line 5
#       2 bot_hsv = (30, 21, 71)
#       3 shs_hsv = (84, 1, 99)
# ----> 5 DisplayOutfitColors((top_hsv, bot_hsv, shs_hsv))
#
# Cell In [32], line 13, in DisplayOutfitColors(outfit, valid_matches)
#      10 colors = [colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0) for hsv in outfit]
#      12 plt.rcdefaults()
# ---> 13 fig, ax = plt.subplots()
#      15 clothing = ('TOP', 'BOTTOM', 'SHOES')
#      16 y_pos = np.arange(len(clothing))
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %%
from random import randint

# %%
for _ in range(10):
    h = randint(0, 360)
    s = randint(0, 100)
    v = randint(0, 100)
    ShowColorWithDesc((h, s, v))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [35], line 5
#       3 s = randint(0, 100)
#       4 v = randint(0, 100)
# ----> 5 ShowColorWithDesc((h, s, v))
#
# Cell In [30], line 11, in ShowColorWithDesc(hsv)
#      10 def ShowColorWithDesc(hsv):
# ---> 11     ShowColor(hsv)
#      12     print(GetColorDesc(hsv))
#
# Cell In [28], line 9, in ShowColor(hsv)
#       7 def ShowColor(hsv):
#       8     rgb = colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0)
# ----> 9     fig, ax = plt.subplots(nrows=1, ncols=1)
#      10     fig.set_size_inches(3, 2)
#      11     ax.set_facecolor(rgb)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %%
top_hsv = (206, 19, 93)
bot_hsv = (30, 21, 71)
shs_hsv = (84, 1, 99)
outfit_hsv = (top_hsv, bot_hsv, shs_hsv)

top = GetColorDesc(top_hsv)
bot = GetColorDesc(bot_hsv)
shs = GetColorDesc(shs_hsv)
outfit_desc = (top, bot, shs)

# %%
ShowColorWithDesc(top_hsv)
ShowColorWithDesc(bot_hsv)
ShowColorWithDesc(shs_hsv)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 ShowColorWithDesc(top_hsv)
#       2 ShowColorWithDesc(bot_hsv)
#       3 ShowColorWithDesc(shs_hsv)
#
# Cell In [30], line 11, in ShowColorWithDesc(hsv)
#      10 def ShowColorWithDesc(hsv):
# ---> 11     ShowColor(hsv)
#      12     print(GetColorDesc(hsv))
#
# Cell In [28], line 9, in ShowColor(hsv)
#       7 def ShowColor(hsv):
#       8     rgb = colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0)
# ----> 9     fig, ax = plt.subplots(nrows=1, ncols=1)
#      10     fig.set_size_inches(3, 2)
#      11     ax.set_facecolor(rgb)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)

# %%
"""
Basic outfit follow these rules
- No more than one bright color
- No high contrast between colors (bright warm + dark cool)
- Any number of neutral colors can fit anywhere
INPUT:
outfit - tuple(top, bot, shs)
    top - tuple(tone, temp)
    bot - tuple(tone, temp)
    shs - tuple(tone, temp)
OUTPUT: 
    True or False
"""
def BasicMatch(outfit):
    top = outfit[0]
    bot = outfit[1] 
    shs = outfit[2]
    
    bright_count = len([i for i in outfit if i[0] == 'BRIGHT'])
    if bright_count > 1: return False
    # Check for high contrast
    
    return True

# %%
BasicMatch(outfit_desc)
# Out:
# True

# %%
"""
Neutral outfit follow these rules
- Only neutral colors
INPUT:
outfit - tuple(top, bot, shs)
    top - tuple(tone, temp)
    bot - tuple(tone, temp)
    shs - tuple(tone, temp)
OUTPUT:
    True or False
"""
def NeutralMatch(outfit):
    top = outfit[0]
    bot = outfit[1] 
    shs = outfit[2]
    
    neutral = [color for color in outfit if color[0] == 'NEUTRAL']
    if len(neutral) != len(outfit):
        return False
    
    return True

# %%
NeutralMatch(outfit_desc)
# Out:
# True

# %%
"""
Analogous outfit follow these rules
- All colors must be within the same temp.
- Any number of neutral colors
INPUT:
outfit - tuple(top, bot, shs)
    top - tuple(tone, temp)
    bot - tuple(tone, temp)
    shs - tuple(tone, temp)
OUTPUT:
    True or False
"""
def AnalogousMatch(outfit):
    top = outfit[0]
    bot = outfit[1] 
    shs = outfit[2]
    
    cool_count = len([color for color in outfit if color[1] == 'COOL'])
    warm_count = len(outfit) - cool_count
    if cool_count < len(outfit) and warm_count < len(outfit):
        return False
    
    return True

# %%
AnalogousMatch(outfit_desc)
# Out:
# False

# %%
"""
Contrast outfit follow these rules
- At least one warm color
- Both dark and bright colors present
INPUT:
outfit - tuple(top, bot, shs)
    top - tuple(tone, temp)
    bot - tuple(tone, temp)
    shs - tuple(tone, temp)
OUTPUT:
    True or False
"""
def ContrastMatch(outfit):
    top = outfit[0]
    bot = outfit[1] 
    shs = outfit[2]
    
    warm_count = len([color for color in outfit if color[1] == 'WARM'])
    if warm_count < 1: return False
    
    dark_count = len([color for color in outfit if color[0] == 'DARK'])
    bright_count = len([color for color in outfit if color[0] == 'BRIGHT'])
    if dark_count < 1 or bright_count < 1:
        return False
    
    return True

# %%
ContrastMatch(outfit_desc)
# Out:
# False

# %%
"""
Bright summer outfit follow these rules
- At least two warm colors
- At least one bright color
- At most one dark color
INPUT:
outfit - tuple(top, bot, shs)
    top - tuple(tone, temp)
    bot - tuple(tone, temp)
    shs - tuple(tone, temp)
OUTPUT: 
    True or False
"""
def SummerMatch(outfit):
    top = outfit[0]
    bot = outfit[1] 
    shs = outfit[2]
    
    non_neutral = [color for color in outfit if color[0] != 'NEUTRAL']
    
    warm_count = len([color for color in non_neutral if color[1] == 'WARM'])
    if warm_count < 2: return False
    
    dark_count = len([color for color in non_neutral if color[0] == 'DARK'])
    if dark_count > 1: return False
    
    bright_count = len(non_neutral) - dark_count
    if bright_count < 1: return False
    
    return True

# %%
SummerMatch(outfit_desc)
# Out:
# False

# %%
"""
Dark winter outfit follow these rules
- At least one dark color
- No bright colors
INPUT:
outfit - tuple(top, bot, shs)
    top - tuple(tone, temp)
    bot - tuple(tone, temp)
    shs - tuple(tone, temp)
OUTPUT:
    True or False
"""
def WinterMatch(outfit):
    top = outfit[0]
    bot = outfit[1] 
    shs = outfit[2]
    
    non_neutral = [color for color in outfit if color[0] != 'NEUTRAL']
    
    dark_count = len([color for color in non_neutral if color[0] == 'DARK'])
    if dark_count < 1: return False
    
    bright_count = len(non_neutral) - dark_count
    if bright_count > 0: return False
    
    return True

# %%
WinterMatch(outfit_desc)
# Out:
# False

# %%
"""
Iterate outfit over all color schemes and get all valid matches
INPUT:
outfit - tuple(top, bot, shs)
    top - hsv
    bot - hsv
    shs - hsv
OUTPUT:
    All names of valid outfit matches
"""
def GetValidMatches(outfit):
    top = GetColorDesc(outfit[0])
    bot = GetColorDesc(outfit[1])
    shs = GetColorDesc(outfit[2])
    outfit_desc = (top, bot, shs)
    
    rules = {"Basic": BasicMatch, "Neutral": NeutralMatch,
             "Analogous": AnalogousMatch, "Summer": SummerMatch,
            "Winter": WinterMatch}
    valid_matches = []
    for key in rules:
        if rules[key](outfit_desc):
            valid_matches.append(key)
    return valid_matches

# %%
"""
male with neutral outfit
top_hsv = (201, 80, 14)
bot_hsv = (210, 18, 39)
shs_hsv = (202, 77, 15)

female with pink shirt
top_hsv = (4, 37, 91)
bot_hsv = (215, 50, 41)
shs_hsv = (2, 26, 47)

woman in winter purple coat
top_hsv = (330, 74, 41)
bot_hsv = (255, 19, 8)
shs_hsv = (0, 0, 15)

male blue shirt
top_hsv = (206, 99, 69)
bot_hsv = (206, 62, 31)
shs_hsv = (211, 12, 97)
-----------------------------------
clown
top_hsv = (162, 51, 67)
bot_hsv = (350, 78, 73)
shs_hsv = (15, 22, 28)

female colorful outfit
top_hsv = (38, 99, 96)
bot_hsv = (360, 72, 73)
shs_hsv = (300, 1, 95)

male with mismatched pink shirt
top_hsv = (343, 44, 100)
bot_hsv = (186, 96, 76)
shs_hsv = (0, 0, 15)
"""

# copy&paste outfit from comments here to test
top_hsv = (330, 74, 41)
bot_hsv = (255, 19, 8)
shs_hsv = (0, 0, 15)
#-----
outfit_hsv = (top_hsv, bot_hsv, shs_hsv)

# %%
DisplayOutfitColors(outfit_hsv, valid_matches=GetValidMatches(outfit_hsv))

top = GetColorDesc(top_hsv)
bot = GetColorDesc(bot_hsv)
shs = GetColorDesc(shs_hsv)
outfit_desc = (top, bot, shs)
print(outfit_desc)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [52], line 1
# ----> 1 DisplayOutfitColors(outfit_hsv, valid_matches=GetValidMatches(outfit_hsv))
#       3 top = GetColorDesc(top_hsv)
#       4 bot = GetColorDesc(bot_hsv)
#
# Cell In [32], line 13, in DisplayOutfitColors(outfit, valid_matches)
#      10 colors = [colorsys.hsv_to_rgb(hsv[0]/360.0, hsv[1]/100.0, hsv[2]/100.0) for hsv in outfit]
#      12 plt.rcdefaults()
# ---> 13 fig, ax = plt.subplots()
#      15 clothing = ('TOP', 'BOTTOM', 'SHOES')
#      16 y_pos = np.arange(len(clothing))
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:1442, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1319 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1320              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1321     """
#    1322     Create a figure and a set of subplots.
#    1323
#    1324     This utility wrapper makes it convenient to create common layouts of
#    1325     subplots, including the enclosing figure object, in a single call.
#    1326
#    1327     Parameters
#    1328     ----------
#    1329     nrows, ncols : int, default: 1
#    1330         Number of rows/columns of the subplot grid.
#    1331
#    1332     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#    1333         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#    1334         axes:
#    1335
#    1336         - True or 'all': x- or y-axis will be shared among all subplots.
#    1337         - False or 'none': each subplot x- or y-axis will be independent.
#    1338         - 'row': each subplot row will share an x- or y-axis.
#    1339         - 'col': each subplot column will share an x- or y-axis.
#    1340
#    1341         When subplots have a shared x-axis along a column, only the x tick
#    1342         labels of the bottom subplot are created. Similarly, when subplots
#    1343         have a shared y-axis along a row, only the y tick labels of the first
#    1344         column subplot are created. To later turn other subplots' ticklabels
#    1345         on, use `~matplotlib.axes.Axes.tick_params`.
#    1346
#    1347         When subplots have a shared axis that has units, calling
#    1348         `~matplotlib.axis.Axis.set_units` will update each axis with the
#    1349         new units.
#    1350
#    1351     squeeze : bool, default: True
#    1352         - If True, extra dimensions are squeezed out from the returned
#    1353           array of `~matplotlib.axes.Axes`:
#    1354
#    1355           - if only one subplot is constructed (nrows=ncols=1), the
#    1356             resulting single Axes object is returned as a scalar.
#    1357           - for Nx1 or 1xM subplots, the returned object is a 1D numpy
#    1358             object array of Axes objects.
#    1359           - for NxM, subplots with N>1 and M>1 are returned as a 2D array.
#    1360
#    1361         - If False, no squeezing at all is done: the returned Axes object is
#    1362           always a 2D array containing Axes instances, even if it ends up
#    1363           being 1x1.
#    1364
#    1365     subplot_kw : dict, optional
#    1366         Dict with keywords passed to the
#    1367         `~matplotlib.figure.Figure.add_subplot` call used to create each
#    1368         subplot.
#    1369
#    1370     gridspec_kw : dict, optional
#    1371         Dict with keywords passed to the `~matplotlib.gridspec.GridSpec`
#    1372         constructor used to create the grid the subplots are placed on.
#    1373
#    1374     **fig_kw
#    1375         All additional keyword arguments are passed to the
#    1376         `.pyplot.figure` call.
#    1377
#    1378     Returns
#    1379     -------
#    1380     fig : `~.figure.Figure`
#    1381
#    1382     ax : `.axes.Axes` or array of Axes
#    1383         *ax* can be either a single `~matplotlib.axes.Axes` object or an
#    1384         array of Axes objects if more than one subplot was created.  The
#    1385         dimensions of the resulting array can be controlled with the squeeze
#    1386         keyword, see above.
#    1387
#    1388         Typical idioms for handling the return value are::
#    1389
#    1390             # using the variable ax for single a Axes
#    1391             fig, ax = plt.subplots()
#    1392
#    1393             # using the variable axs for multiple Axes
#    1394             fig, axs = plt.subplots(2, 2)
#    1395
#    1396             # using tuple unpacking for multiple Axes
#    1397             fig, (ax1, ax2) = plt.subplots(1, 2)
#    1398             fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#    1399
#    1400         The names ``ax`` and pluralized ``axs`` are preferred over ``axes``
#    1401         because for the latter it's not clear if it refers to a single
#    1402         `~.axes.Axes` instance or a collection of these.
#    1403
#    1404     See Also
#    1405     --------
#    1406     .pyplot.figure
#    1407     .pyplot.subplot
#    1408     .pyplot.axes
#    1409     .Figure.subplots
#    1410     .Figure.add_subplot
#    1411
#    1412     Examples
#    1413     --------
#    1414     ::
#    1415
#    1416         # First create some toy data:
#    1417         x = np.linspace(0, 2*np.pi, 400)
#    1418         y = np.sin(x**2)
#    1419
#    1420         # Create just a figure and only one subplot
#    1421         fig, ax = plt.subplots()
#    1422         ax.plot(x, y)
#    1423         ax.set_title('Simple plot')
#    1424
#    1425         # Create two subplots and unpack the output array immediately
#    1426         f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#    1427         ax1.plot(x, y)
#    1428         ax1.set_title('Sharing Y axis')
#    1429         ax2.scatter(x, y)
#    1430
#    1431         # Create four polar axes and access them through the returned array
#    1432         fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
#    1433         axs[0, 0].plot(x, y)
#    1434         axs[1, 1].scatter(x, y)
#    1435
#    1436         # Share a X axis with each column of subplots
#    1437         plt.subplots(2, 2, sharex='col')
#    1438
#    1439         # Share a Y axis with each row of subplots
#    1440         plt.subplots(2, 2, sharey='row')
#    1441
# -> 1442         # Share both X and Y axes with all subplots
#    1443         plt.subplots(2, 2, sharex='all', sharey='all')
#    1444
#    1445         # Note that this is the same as
#    1446         plt.subplots(2, 2, sharex=True, sharey=True)
#    1447
#    1448         # Create figure number 10 with a single subplot
#    1449         # and clears it if it already exists.
#    1450         fig, ax = plt.subplots(num=10, clear=True)
#    1451
#    1452     """
#    1453     fig = figure(**fig_kw)
#    1454     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1455                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1456                        gridspec_kw=gridspec_kw)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\_api\deprecation.py:454, in wrapper(*args, **kwargs)
#     448 @functools.wraps(func)
#     449 def wrapper(*args, **kwargs):
#     450     # Don't use signature.bind here, as it would fail when stacked with
#     451     # rename_parameter and an "old" argument name is passed in
#     452     # (signature.bind would fail, but the actual call would succeed).
#     453     if len(args) > name_idx:
# --> 454         warn_deprecated(
#     455             since, message="Passing the %(name)s %(obj_type)s "
#     456             "positionally is deprecated since Matplotlib %(since)s; the "
#     457             "parameter will become keyword-only %(removal)s.",
#     458             name=name, obj_type=f"parameter of {func.__name__}()")
#     459     return func(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:783, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     781 elif isinstance(num, str):
#     782     fig_label = num
# --> 783     all_labels = get_figlabels()
#     784     if fig_label not in all_labels:
#     785         if fig_label == 'all':
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:358, in new_figure_manager(*args, **kwargs)
#     342 def show(*args, **kwargs):
#     343     """
#     344     Display all open figures.
#     345
#     346     Parameters
#     347     ----------
#     348     block : bool, optional
#     349         Whether to wait for all figures to be closed before returning.
#     350
#     351         If `True` block and run the GUI main loop until all figure windows
#     352         are closed.
#     353
#     354         If `False` ensure that all figure windows are displayed and return
#     355         immediately.  In this case, you are responsible for ensuring
#     356         that the event loop is running to have responsive figures.
#     357
# --> 358         Defaults to True in non-interactive mode and to False in interactive
#     359         mode (see `.pyplot.isinteractive`).
#     360
#     361     See Also
#     362     --------
#     363     ion : Enable interactive mode, which shows / updates the figure after
#     364           every plotting command, so that calling ``show()`` is not necessary.
#     365     ioff : Disable interactive mode.
#     366     savefig : Save the figure to an image file instead of showing it on screen.
#     367
#     368     Notes
#     369     -----
#     370     **Saving figures to file and showing a window at the same time**
#     371
#     372     If you want an image file as well as a user interface window, use
#     373     `.pyplot.savefig` before `.pyplot.show`. At the end of (a blocking)
#     374     ``show()`` the figure is closed and thus unregistered from pyplot. Calling
#     375     `.pyplot.savefig` afterwards would save a new and thus empty figure. This
#     376     limitation of command order does not apply if the show is non-blocking or
#     377     if you keep a reference to the figure and use `.Figure.savefig`.
#     378
#     379     **Auto-show in jupyter notebooks**
#     380
#     381     The jupyter backends (activated via ``%matplotlib inline``,
#     382     ``%matplotlib notebook``, or ``%matplotlib widget``), call ``show()`` at
#     383     the end of every cell by default. Thus, you usually don't have to call it
#     384     explicitly there.
#     385     """
#     386     _warn_if_gui_out_of_main_thread()
#     387     return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:336, in _warn_if_gui_out_of_main_thread()
#     329 def draw_if_interactive(*args, **kwargs):
#     330     """
#     331     Redraw the current figure if in interactive mode.
#     332
#     333     .. warning::
#     334
#     335         End users will typically not have to call this function because the
# --> 336         the interactive mode takes care of this.
#     337     """
#     338     return _get_backend_mod().draw_if_interactive(*args, **kwargs)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:207, in _get_backend_mod()
#     201     return getattr(
#     202         backend_mod.FigureCanvas, "required_interactive_framework", None)
#     204 _backend_mod = None
# --> 207 def _get_backend_mod():
#     208     """
#     209     Ensure that a backend is selected and return it.
#     210
#     211     This is currently private, but may be made public in the future.
#     212     """
#     213     if _backend_mod is None:
#     214         # Use __getitem__ here to avoid going through the fallback logic (which
#     215         # will (re)import pyplot and then call switch_backend if we need to
#     216         # resolve the auto sentinel)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\pyplot.py:265, in switch_backend(newbackend)
#     263 except ImportError:
#     264     continue
# --> 265 else:
#     266     rcParamsOrig['backend'] = candidate
#     267     return
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\__init__.py:1
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib_inline\backend_inline.py:8
#       6 import matplotlib
#       7 from matplotlib import colors
# ----> 8 from matplotlib.backends import backend_agg
#       9 from matplotlib.backends.backend_agg import FigureCanvasAgg
#      10 from matplotlib._pylab_helpers import Gcf
#
# File c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backends\backend_agg.py:37
#      35 from matplotlib import _api, cbook
#      36 from matplotlib import colors as mcolors
# ---> 37 from matplotlib.backend_bases import (
#      38     _Backend, _check_savefig_extra_args, FigureCanvasBase, FigureManagerBase,
#      39     RendererBase)
#      40 from matplotlib.font_manager import findfont, get_font
#      41 from matplotlib.ft2font import (LOAD_FORCE_AUTOHINT, LOAD_NO_HINTING,
#      42                                 LOAD_DEFAULT, LOAD_NO_AUTOHINT)
#
# ImportError: cannot import name '_check_savefig_extra_args' from 'matplotlib.backend_bases' (c:\Users\Cristiana\anaconda3\envs\finalproject\lib\site-packages\matplotlib\backend_bases.py)
